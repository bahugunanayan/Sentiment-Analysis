# %%
# !pip install tweepy

# %%
# !pip install configparser

# %%
import os
import tweepy as tw
import pandas as pd
from tweepy import OAuthHandler

# %%
# Store information about authentication and authorization for Twitter API
consumer_key= '3LRBJrrEexLr867EpPz6dgnRZ'
consumer_secret= '5EVaVQwfwmsdzzOAdqP8kidpOmDiYPVtltF1J7o3bEHXrl359h'
access_token= '1322098174803267585-r1muwqWHwz2rGeW1zLVEFjr0tJZmnF'
access_token_secret= 'nxfHK4W4pAT8uxXGF6Tf51XwCf6KSfjNVn2ODsOZd4smT'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Define the search term and the date_since date as variables
search_words = "Raining"
date_since = "2022-07-11"
date_until="2022-07-14"

# %%
# Collect tweets
tweets = tw.Cursor(api.search_tweets,
              q=search_words,
              lang="en",
              since=date_since,
              until=date_until ).items(100)

# %%
# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# Unexpected parameter: since
# Unexpected parameter: since
# RT @RetardedHurt: Girls- Yarr it's raining so heavily ya,I can't step out of my house yaa,mera make up kharab ho jayega,let's meet some oth…
# RT @fluffho: Shaoshang's riding Buyi's carriage cause it's raining and she saw the arrow that penetrated Buyi, WHICH HE STILL KEEPS LIKE IT…
# RT @femcel_girlboss: I'm going to destroy twitter so we can all become amish and stop thinking
# RT @puiymysiri: Raining on the dance floor 🤩
# #team_h
# https://t.co/1cKmczJ09M
# RT @JacksonWang852: Thank you so much for having me,
# Its my honor to be here,
# Hope u all are warmed up for the game
# Let’s watch it together…
# @hannytomi My area during all these endless raining days... If e like make e fall fire, them no dey take the light.
# RT @goeunbbl: 🍒💭[22.07.13] 9:13pm KST
#
# - Plory, 🐱 is here!
# - Did you have a good day?😘
# - I don't know if it's because it's raining
# - It was…
# @LAYOR21 It’s not been raining there
# ...

# %% [markdown]
# #  Twitter Trend
#
#
# Trends API is a part of twitter API that is used to return the top 50 trending topics for a specific WOEID location from the twitter server. It is used to extract data from the twitter server about the trending topics in the specified location.

# %%
! pip install twitter

# %%
import twitter

consumer_key= '3LRBJrrEexLr867EpPz6dgnRZ'
consumer_secret= '5EVaVQwfwmsdzzOAdqP8kidpOmDiYPVtltF1J7o3bEHXrl359h'
access_token= '1322098174803267585-r1muwqWHwz2rGeW1zLVEFjr0tJZmnF'
access_token_secret= 'nxfHK4W4pAT8uxXGF6Tf51XwCf6KSfjNVn2ODsOZd4smT'
auth = twitter.oauth.OAuth(access_token, access_token_secret,consumer_key, consumer_secret)

twitter_api = twitter.Twitter(auth=auth)

# %%
twitter_api.trends.available()
# Out:
# [{'name': 'Worldwide',
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'parentid': 0,
#   'country': '',
#   'woeid': 1,
#   'countryCode': None},
#  {'name': 'Winnipeg',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 2972,
#   'countryCode': 'CA'},
#  {'name': 'Ottawa',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3369,
#   'countryCode': 'CA'},
#  {'name': 'Quebec',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3444,
#   'countryCode': 'CA'},
#  {'name': 'Montreal',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
# ...

# %%
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/

WORLD_WOE_ID = 1
IN_WOE_ID = 2282863

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
IN_trends = twitter_api.trends.place(_id=IN_WOE_ID)

print (world_trends)
# Out:
# [{'trends': [{'name': '#FNS歌謡祭夏', 'url': 'http://twitter.com/search?q=%23FNS%E6%AD%8C%E8%AC%A1%E7%A5%AD%E5%A4%8F', 'promoted_content': None, 'query': '%23FNS%E6%AD%8C%E8%AC%A1%E7%A5%AD%E5%A4%8F', 'tweet_volume': 217455}, {'name': '#Origin', 'url': 'http://twitter.com/search?q=%23Origin', 'promoted_content': None, 'query': '%23Origin', 'tweet_volume': None}, {'name': '#VoleiNoSporTV', 'url': 'http://twitter.com/search?q=%23VoleiNoSporTV', 'promoted_content': None, 'query': '%23VoleiNoSporTV', 'tweet_volume': None}, {'name': '#PMQs', 'url': 'http://twitter.com/search?q=%23PMQs', 'promoted_content': None, 'query': '%23PMQs', 'tweet_volume': 25402}, {'name': '#MsMarvel', 'url': 'http://twitter.com/search?q=%23MsMarvel', 'promoted_content': None, 'query': '%23MsMarvel', 'tweet_volume': 57198}, {'name': 'リンライ', 'url': 'http://twitter.com/search?q=%E3%83%AA%E3%83%B3%E3%83%A9%E3%82%A4', 'promoted_content': None, 'query': '%E3%83%AA%E3%83%B3%E3%83%A9%E3%82%A4', 'tweet_volume': 10867}, {'name'
# ...

# %%
IN_trends[0]['trends'][0]['name']
# Out:
# '#MumbaiKhiladis'

# %%
Toptrend=[]

for i in range(0,40):
    x=IN_trends[0]['trends'][i]['name']  
    Toptrend.append(x)
    
Toptrend
# Out:
# ['#MumbaiKhiladis',
#  '#Epaylater',
#  '#MsMarvel',
#  '#GuruPurnima',
#  'गुरु पूर्णिमा',
#  'SSRCase Exposes Justice System',
#  'Taranga Hill-Ambaji-Abu Road',
#  'New Launches',
#  'Great Deals',
#  'Victor',
#  'Block Buster Entertainment',
#  'Vietnam',
#  'Maldives',
#  'Colombo',
#  'Nagaland',
#  'JUNG HOSEOK',
#  'NEET',
#  'Lewa',
#  '#boosterdose',
#  '#CabinetDecisions',
#  '#kashmiragainstterrorism',
#  '#GuluGuluTeaser',
#  '#NayiPatriNayiRaftaar',
#  '#Astraverse',
#  '#DiscoverJoy',
#  '#AmazonPrimeDay',
#  '#मोदी_मंदी_और_महंगाई',
#  '#hijab',
#  '#ICCRankings',
#  '#OPPO',
#  '#SriLanka',
#  '#Eeswarude',
#  '#RheaChakraborty',
#  '#lifetested',
#  '#ranilwickremesinghe',
#  '#motog71',
#  '#POCOC31',
#  '#अशोक_स्तंभ_मत_बदलो',
#  '#AskSudhir',
#  '#Billa2']

# %%
 # Collect data for Top trend say #Hockey
search_words = "#GuruPurnima"+'-filter:retweets'

# Collect tweets
tweets = tw.Cursor(api.search_tweets,q=search_words, woeid= "28.667856, 77.449791,10mi",lang="en").items(700)

# Iterate and print tweets
for tweet in tweets:
    print(tweet.text)
# Out:
# Unexpected parameter: woeid
# Unexpected parameter: woeid
# Let the right decisions take you on the correct path of your betterment and be your guiding light towards a brighte… https://t.co/mZWvu96BfM
# Nothing more precious than the blessings of the teacher. Blessed by my teachers Shri. Satish Dalvi sir &amp; Shri. Vall… https://t.co/gfHrooHoHF
# #GuruPurnima
# Presently there is Sant Rampal Ji Maharaj who is a complete Guru.  All religions tell the proven knowl… https://t.co/Z4CrFzIyDr
# #VarunDhawan teases 'Bawaal' co-star #JanhviKapoor by wishing her on #GuruPurnima - check out her epic reaction… https://t.co/NN9IH5HAc8
# Today is the best day to pay tribute to all the gurus in our life.
# HAPPY GURU PURNIMA!
#
# #gurupurnima… https://t.co/IiSySgZocb
# Guru is everything in our life, nothing is possible without them. Happy Guru Purnima!
#
# #kcco… https://t.co/SE0jZaFKuh
# ...

# %% [markdown]
#                          Text Analysis (Cleaning)

# %%
# Collect data for #covid
search_words = "#Japan"+'-filter:retweets'

# Collect tweets
tweets_list = tw.Cursor(api.search_tweets, q=search_words,lang="en").items(300)

output = []
for tweet in tweets_list:
    text = tweet._json["text"]
    output.append(text)
# Out:
# Rate limit reached. Sleeping for: 209

# %%
output
# Out:
# ['Kyouko Sakura versus Sayaka Miki in the series was well done. But this all-out shootout between Homura and Mami in… https://t.co/1PHhpSRrf9',
#  'Field Recordings and some shoe gazy stuff \n\nhttps://t.co/Hjkk3hdguJ\n\n #AndyBell #commonmetals  #distantduos… https://t.co/olr4ZuJMfq',
#  '@ItsMeDeaner is it just us or we receive 200 dick photos and dog photos everyday? #japan',
#  'Is #Japan really the crypto-friendliest country in the world? The #TokenScope Team makes an overview of Japan’s dig… https://t.co/qhjXnmKf1s',
#  'Bounce back Japan !!! Hoping for a reverse sweep !!!\n\n#VNL\n#VNLFinals\n#Japan\n#Volleyball',
#  '#Japan bids farewell to Shinzo Abe #安倍晋三 \n🇯🇵🙏🇮🇳\n\nhttps://t.co/fASfZhq29P',
#  'Japan’s #Womenomics Needs Reboot To Boost GDP By 15% via @forbes #Japan #ShinzoAbe #WEF \nhttps://t.co/JbgMmYmgfu',
#  '#Japan Meteorological Agency\n\n【#RiskMaps】\n #Inundation, #Landslide, #Flood\n\n【#Precipitation Nowcasts】\n#Lightening,… https://t.co/3ids5B4JXv',
# ...

# %%
output = pd.DataFrame(output)
# saving the dataframe
output.to_csv('D:\\executive_Batch\\BA_Executive_BA\\Business Analytics\\file1.csv',header=['Tweets'])

# %%
# Reading csv file 
dataset=pd.read_csv('D:\\executive_Batch\\BA_Executive_BA\\Business Analytics\\file1.csv')
dataset.columns=['Index', 'Tweets']

dataset
# Out:
#      Index                                             Tweets
# 0        0  Kyouko Sakura versus Sayaka Miki in the series...
# 1        1  Field Recordings and some shoe gazy stuff \n\n...
# 2        2  @ItsMeDeaner is it just us or we receive 200 d...
# 3        3  Is #Japan really the crypto-friendliest countr...
# 4        4  Bounce back Japan !!! Hoping for a reverse swe...
# ..     ...                                                ...
# 295    295  #TECHNOS MEN'S Quartz W.R.10ATM #T4B20BN ￥38,5...
# 296    296  The #USD is putting other #currencies under su...
# 297    297  #Vacancy in #Tokyo #Japan: Minimum 10 years of...
# 298    298  Can you play this game too? #Japan #RomanceOfT...
# 299    299  #AmazingChina #China #Shandong #Japan\n\nOn th...
#
# [300 rows x 2 columns]

# %% [markdown]
# # Sub()
# sub() function belongs to the Regular Expressions ( re ) module in Python. It returns a string where all matching occurrences of the specified pattern are replaced by the replace string.

# %%
# Create a function to clean the tweets

import re

def cleanTxt(text):

    text=re.sub(r'@[A-Za-z0-9]','',text)  # Removed @ mentions
    text=re.sub(r'#','',text)  # Removing '#' symbole
    text=re.sub(r'RT[\s]+','', text)  # Removing RT
    text=re.sub(r'https?:\/\/S+','',text) # Removing the Hyperlink
    text=re.sub(r'\n','',text)  # Removed space mentions
    text=re.sub(r',','',text)  # Removed space mentions
    return text
 
dataset['Tweets']=dataset['Tweets'].apply(cleanTxt)
dataset['Tweets']

# %% [markdown]
# def remove_emoji(string):
#     emoji_pattern = re.compile("["
#                            u"U0001F600-U0001F64F"  # emoticons
#                            u"U0001F300-U0001F5FF"  # symbols & pictographs
#                            u"U0001F680-U0001F6FF"  # transport & map symbols
#                            u"U0001F1E0-U0001F1FF"  # flags (iOS)
#                            u"U00002702-U000027B0"
#                            u"U000024C2-U0001F251"
#                            "]+", flags=re.UNICODE)
#     return emoji_pattern.sub(r'', string)
# remove_emoji("game is on 🔥🔥")
# #Output
# 'game is on '

# %%
#Load in the NTLK stopwords to remove words that are not actionable
from nltk.corpus import stopwords
# This allows to create individual objects from a bog of words
from nltk.tokenize import word_tokenize
# Lemmatizer helps to reduce words to the base form
from nltk.stem import WordNetLemmatizer
# Ngrams allows to group words in common pairs or trigrams..etc
from nltk import ngrams
# We can use counter to count the objects
from collections import Counter
# This is our visual library
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import string
sentence=dataset['Tweets'].to_string()

# creates tokens, creates lower class, removes numbers and lemmatizes the words
new_tokens = word_tokenize(sentence)

new_tokens = [t.lower() for t in new_tokens]

new_tokens =[t for t in new_tokens if t not in stopwords.words('english')]

new_tokens = [t for t in new_tokens if t.isalpha()]

lemmatizer = WordNetLemmatizer()

new_tokens =[lemmatizer.lemmatize(t) for t in new_tokens]

# %%
new_tokens

# %%
#Counts the words, pairs and trigrams

counted = Counter(new_tokens)

counted_2= Counter(ngrams(new_tokens,2))

counted_3= Counter(ngrams(new_tokens,3))

#creates 3 data frames and returns thems

word_freq = pd.DataFrame(counted.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)

word_pairs =pd.DataFrame(counted_2.items(),columns=['pairs','frequency']).sort_values(by='frequency',ascending=False)

trigrams =pd.DataFrame(counted_3.items(),columns=['trigrams','frequency']).sort_values(by='frequency',ascending=False)

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(max_words = 1000,  width = 600,   height = 400,background_color = 'black').generate((sentence))

plt.imshow(wordcloud,interpolation="bilinear")

plt.axis('off')

plt.show()

# %%
#Create subplot of the different data frames

fig, axes = plt.subplots(3,1,figsize=(8,20))

sns.barplot(ax=axes[0],x='frequency',y='word',data=word_freq.head(30))

sns.barplot(ax=axes[1],x='frequency',y='pairs',data=word_pairs.head(30))

sns.barplot(ax=axes[2],x='frequency',y='trigrams',data=trigrams.head(30))

# %% [markdown]
# #                                   Sentiment Analysis
